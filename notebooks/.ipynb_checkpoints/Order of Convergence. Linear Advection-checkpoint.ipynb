# %% [markdown]
# # Order of convergence of FVM schemes
# Consider the linear transport equation:
#
# $u_t + a u_x = 0$
#
# with initial conditions:
#
# $u(x,0) = \sin(4\pi x)$
#
# The exact solution of the problem is $u(x,t) = \sin (4 \pi (x-t))$
#
# Let's plot the exact solution at time = 2 (note that the exact solution returns back to the initial condition at time $t = k$ for all positive integer $k$).

# %%
using Plots

# %%
u_exact(x,t) = sin(4*pi*(x-t))
# Out:
# u_exact (generic function with 1 method)

# %%
plot(0:0.01:1, [u_exact(x,10.0) for x in 0:0.01:1])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9000">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9001">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9000)" points="
# 45.7332,375.813 580.315,375.813 580.315,11.811 45.7332,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9002">
#     <rect x="45" y="11" width="536" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,375.813 45.7332,11.811
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   152.65,375.813 152.65,11.811
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   259.566,375.813 259.566,11.811
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   366.482,375.813 366.482,11.811
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   473.399,375.813 473.399,11.811
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,330.583 580.315,330.583
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,284.993 580.315,284.993
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,239.403 580.315,239.403
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,193.812 580.315,193.812
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,148.222 580.315,148.222
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,102.632 580.315,102.632
#   "/>
# <polyline clip-path="url(#clip9002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,57.0414 580.315,57.0414
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,11.811
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,370.353
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   152.65,375.813 152.65,370.353
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   259.566,375.813 259.566,370.353
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   366.482,375.813 366.482,370.353
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   473.399,375.813 473.399,370.353
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,330.583 53.7519,330.583
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,284.993 53.7519,284.993
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,239.403 53.7519,239.403
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,193.812 53.7519,193.812
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,148.222 53.7519,148.222
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,102.632 53.7519,102.632
#   "/>
# <polyline clip-path="url(#clip9000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,57.0414 53.7519,57.0414
#   "/>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.7332, 389.613)" x="45.7332" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 152.65, 389.613)" x="152.65" y="389.613">0.2</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 259.566, 389.613)" x="259.566" y="389.613">0.4</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 366.482, 389.613)" x="366.482" y="389.613">0.6</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 473.399, 389.613)" x="473.399" y="389.613">0.8</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">1.0</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 335.083)" x="39.7332" y="335.083">-0.75</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 289.493)" x="39.7332" y="289.493">-0.50</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 243.903)" x="39.7332" y="243.903">-0.25</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 198.312)" x="39.7332" y="198.312">0.00</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 152.722)" x="39.7332" y="152.722">0.25</text>
# </g>
# <g clip-path="url(#clip9000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 107.132)"

# %% [markdown]
# For the numerical solution, first we setup the problem:

# %%
using ConservationLawsDiffEq
# Define the flux and flux Jacobian
f(::Type{Val{:jac}},u::Vector) = eye(size(u,1))
f(u::Vector) = u

# Initial condition (using integral cell averages)
function u0_func(mesh)
  N = numcells(mesh)
  uinit = fill(0.0,N,1)
  faces = cell_faces(mesh)
  for i in 1:N
      uinit[i,1] = num_integrate(x->sin(4*pi*x),faces[i], faces[i+1])/volume(i, mesh)
  end
  return uinit
end

#Setup problem for a given N (number of cells/control volumenes on a uniform mesh)
#and given final time (Tend) with periodic boundary conditions
function get_problem(N; Tend = 2.0, CFL = 0.5)
  mesh = Uniform1DFVMesh(N,0.0,1.0,:PERIODIC, :PERIODIC)
  u0 = u0_func(mesh)
  ConservationLawsProblem(u0,f,CFL,Tend,mesh)
end
# Out:
# get_problem (generic function with 1 method)

# %% [markdown]
# *Remark:* Note that in flux and flux jacobian definition we assume that $u$ is a vector even in the scalar case.
#
# Now we approximate the solution using a first order Lax-Friedrichs scheme.

# %%
prob = get_problem(50)
sol1 = solve(prob, LaxFriedrichsAlgorithm();TimeIntegrator = Euler(), use_threads = true, save_everystep = false);

# %% [markdown]
# Let's compare the numerical solution against the exact solution:

# %%
plot(0:0.01:1, [u_exact(x,10.0) for x in 0:0.01:1], lab="u exact")
plot!(sol1, lab="u LF")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9200)" points="
# 61.4812,360.065 580.315,360.065 580.315,11.811 61.4812,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9202">
#     <rect x="61" y="11" width="520" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,360.065 61.4812,11.811
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   165.248,360.065 165.248,11.811
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   269.015,360.065 269.015,11.811
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   372.781,360.065 372.781,11.811
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   476.548,360.065 476.548,11.811
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,360.065 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,316.792 580.315,316.792
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,273.174 580.315,273.174
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,229.556 580.315,229.556
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,185.938 580.315,185.938
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,142.32 580.315,142.32
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,98.7025 580.315,98.7025
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,55.0846 580.315,55.0846
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 61.4812,11.811
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 61.4812,354.842
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   165.248,360.065 165.248,354.842
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   269.015,360.065 269.015,354.842
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   372.781,360.065 372.781,354.842
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   476.548,360.065 476.548,354.842
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,354.842
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,316.792 69.2638,316.792
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,273.174 69.2638,273.174
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,229.556 69.2638,229.556
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,185.938 69.2638,185.938
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,142.32 69.2638,142.32
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,98.7025 69.2638,98.7025
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,55.0846 69.2638,55.0846
#   "/>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 61.4812, 373.865)" x="61.4812" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 165.248, 373.865)" x="165.248" y="373.865">0.2</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.015, 373.865)" x="269.015" y="373.865">0.4</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 372.781, 373.865)" x="372.781" y="373.865">0.6</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 476.548, 373.865)" x="476.548" y="373.865">0.8</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">1.0</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 321.292)" x="55.4812" y="321.292">-0.75</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 277.674)" x="55.4812" y="277.674">-0.50</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 234.056)" x="55.4812" y="234.056">-0.25</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 190.438)" x="55.4812" y="190.438">0.00</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 146.82)" x="55.4812" y="146.82">0.25</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 103.202)"

# %% [markdown]
# Finite volume schemes like the Gudonov, Lax-Friedrichs and Engquist-Osher are quite stable with no spurious oscillations or other numerical artifacts. However, the approximation may lead to large errors, particulary at coarse meshes.
#
# An explanation for the large errors is provided in the experimental order of convergence. The observed order of convergence is close to one. This implies that the convergence is slow and errors are reduced very slowly.

# %%
#Define No of cells for each iteration
mesh_ncells = [40,80,160,320,640,1280,2560]
t1 = get_conv_order_table(LaxFriedrichsAlgorithm(), get_problem, u_exact, mesh_ncells; TimeIntegrator = Euler(), use_threads = true)
# Out:
# | M    |   $e_{tot}^{M}$   |    $\theta_{M}$     |
# |:---- |:-----------------:|:-------------------:|
# | 40   | 99.79013742443901 |         0.0         |
# | 80   | 94.90615413024268 | 0.07239559554696695 |
# | 160  | 77.2778683400642  |  0.296446342023336  |
# | 320  | 52.3066922722759  | 0.5630597579802934  |
# | 640  | 30.93589866424936 | 0.7577135971838509  |
# | 1280 | 16.89456016824656 |  0.872723151777703  |
# | 2560 | 8.837690705105738 | 0.9348174452443723  |

# %% [markdown]
# The table shows the relative error in $L^1$ on a sequence of meshes. The percentage relative error is defined by
#
# $$ e_{\Delta x} = 100 \times \frac{\Vert u_{\Delta x} - u_{\mathrm{ref}}\Vert_{L^1}}{\Vert u_{\mathrm{ref}} \Vert_{L^1}} $$
# where $u_{\Delta x}$ is the approximate solution computed on a mesh with cell size $\Delta x$ and $u_{\mathrm{ref}}$ is a reference solution to the continuous problem. We also shown the *experimental order of convergence*,
#
# $$ \theta_{\Delta y} = \frac {\log(e_{\Delta x}) - \log(e_{\Delta y})}{\log(\Delta x) - \log(\Delta y)} $$

# %% [markdown]
# Now, we test a second order numerical scheme: Lax-Wendroff scheme.

# %%
prob = get_problem(50)
@time sol2 = solve(prob, LaxWendroffAlgorithm();save_everystep = false, use_threads=true, TimeIntegrator = Euler())
plot(0:0.01:1, [u_exact(x,10.0) for x in 0:0.01:1], lab="u exact")
plot!(sol2, lab="u LW")
# Out:
#   0.974944 seconds (743.77 k allocations: 51.204 MiB)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9400)" points="
# 61.4812,360.065 580.315,360.065 580.315,11.811 61.4812,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9402">
#     <rect x="61" y="11" width="520" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,360.065 61.4812,11.811
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   165.248,360.065 165.248,11.811
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   269.015,360.065 269.015,11.811
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   372.781,360.065 372.781,11.811
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   476.548,360.065 476.548,11.811
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,360.065 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,316.792 580.315,316.792
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,273.174 580.315,273.174
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,229.556 580.315,229.556
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,185.938 580.315,185.938
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,142.32 580.315,142.32
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,98.7025 580.315,98.7025
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,55.0846 580.315,55.0846
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 61.4812,11.811
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 61.4812,354.842
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   165.248,360.065 165.248,354.842
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   269.015,360.065 269.015,354.842
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   372.781,360.065 372.781,354.842
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   476.548,360.065 476.548,354.842
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,354.842
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,316.792 69.2638,316.792
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,273.174 69.2638,273.174
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,229.556 69.2638,229.556
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,185.938 69.2638,185.938
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,142.32 69.2638,142.32
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,98.7025 69.2638,98.7025
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,55.0846 69.2638,55.0846
#   "/>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 61.4812, 373.865)" x="61.4812" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 165.248, 373.865)" x="165.248" y="373.865">0.2</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.015, 373.865)" x="269.015" y="373.865">0.4</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 372.781, 373.865)" x="372.781" y="373.865">0.6</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 476.548, 373.865)" x="476.548" y="373.865">0.8</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">1.0</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 321.292)" x="55.4812" y="321.292">-0.75</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 277.674)" x="55.4812" y="277.674">-0.50</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 234.056)" x="55.4812" y="234.056">-0.25</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 190.438)" x="55.4812" y="190.438">0.00</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 146.82)" x="55.4812" y="146.82">0.25</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 103.202)"

# %%
t2 = get_conv_order_table(LaxWendroffAlgorithm(), get_problem, u_exact, mesh_ncells; TimeIntegrator = Euler(), use_threads = true)
# Out:
# | M    |    $e_{tot}^{M}$     |    $\theta_{M}$    |
# |:---- |:--------------------:|:------------------:|
# | 40   |  30.14922329298506   |        0.0         |
# | 80   |  7.716077578226222   | 1.9661812821893132 |
# | 160  |  1.936671460451366   | 1.994288414489363  |
# | 320  | 0.48451707577337894  | 1.998959817606854  |
# | 640  | 0.12113651869039188  | 1.9999136553764534 |
# | 1280 | 0.030283373548803238 |  2.00003602116617  |
# | 2560 | 0.00757072777137575  | 2.0000220318454036 |

# %% [markdown]
# Convergence plot

# %%
plot(t1)
plot!(t2)
# Out:
# WARNING: scale log is unsupported with Plots.GRBackend().  Choose from: Symbol[:identity, :log10]
# WARNING: scale log is unsupported with Plots.GRBackend().  Choose from: Symbol[:identity, :log10]
# WARNING: scale log is unsupported with Plots.GRBackend().  Choose from: Symbol[:identity, :log10]
# WARNING: scale log is unsupported with Plots.GRBackend().  Choose from: Symbol[:identity, :log10]
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9600)" points="
# 63.745,360.065 580.315,360.065 580.315,11.811 63.745,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9602">
#     <rect x="63" y="11" width="518" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   106.056,360.065 106.056,11.811
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   177.556,360.065 177.556,11.811
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.057,360.065 249.057,11.811
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   320.557,360.065 320.557,11.811
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   392.057,360.065 392.057,11.811
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   463.558,360.065 463.558,11.811
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   535.058,360.065 535.058,11.811
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   63.745,349.849 580.315,349.849
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   63.745,265.32 580.315,265.32
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   63.745,180.791 580.315,180.791
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   63.745,96.2627 580.315,96.2627
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.745,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.745,360.065 63.745,11.811
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   106.056,360.065 106.056,354.842
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   177.556,360.065 177.556,354.842
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.057,360.065 249.057,354.842
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   320.557,360.065 320.557,354.842
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   392.057,360.065 392.057,354.842
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   463.558,360.065 463.558,354.842
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   535.058,360.065 535.058,354.842
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.745,349.849 71.4935,349.849
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.745,265.32 71.4935,265.32
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.745,180.791 71.4935,180.791
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.745,96.2627 71.4935,96.2627
#   "/>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 88.7582, 378.817)" x="88.7582" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 101.937, 371.965)" x="101.937" y="371.965">1.75 </text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 160.259, 378.817)" x="160.259" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 173.438, 371.965)" x="173.438" y="371.965">2.00 </text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 231.759, 378.817)" x="231.759" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 244.938, 371.965)" x="244.938" y="371.965">2.25 </text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 303.259, 378.817)" x="303.259" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 316.439, 371.965)" x="316.439" y="371.965">2.50 </text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 374.76, 378.817)" x="374.76" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 387.939, 371.965)" x="387.939" y="371.965">2.75 </text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 446.26, 378.817)" x="446.26" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 459.439, 371.965)" x="459.439" y="371.965">3.00 </text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 517.76, 378.817)" x="517.76" y="378.817">10</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:10; text-anchor:start;" transform="rotate(0, 530.94, 371.965)" x="530.94" y="371.965">3.25 </text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,

# %% [markdown]
# # Remarks
#
# * Note that we are using the method of lines to solve each problem. The default time integration algorithm is a second order strong stability preserving Runge-Kutta or SSPRK22 but we use Forward Euler for error estimation. We can change the time integration scheme by using:
#
# ```julia
# #Solve problem using Lax Friedrichs scheme and Strong Stability Preserving RK33
# @time sol = solve(prob, LaxFriedrichsAlgorithm();TimeIntegrator = SSPRK33())
# ```
#
# * We fixed the CFL to 0.5. Important properties like convergence or TVD can be guaranteed only if an appropriate CFL condition is met

# %% [markdown]
# ## References
# * Siddartha Misha, Numerical Methods for conservation laws and related equations, [https://www2.math.ethz.ch/education/bachelor/lectures/fs2013/math/nhdgl/numcl_notes_HOMEPAGE.pdf]
